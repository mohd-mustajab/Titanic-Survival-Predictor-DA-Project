# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv("../data/titanic_cleaned.csv")
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch   Fare Embarked
# 0         0       1    male  44.8      4      1  78.93        S
# 1         1       3    male  38.6      1      4  60.88        Q
# 2         1       3  female  39.6      3      3  15.95        S
# 3         0       3    male  10.9      2      3   1.81        S
# 4         0       3    male  47.0      0      4  20.68        S

# %%
# Basic Info
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1000 non-null   int64
#  1   Pclass    1000 non-null   int64
#  2   Sex       951 non-null    object
#  3   Age       1000 non-null   float64
#  4   SibSp     1000 non-null   int64
#  5   Parch     1000 non-null   int64
#  6   Fare      1000 non-null   float64
#  7   Embarked  1000 non-null   object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 62.6+ KB
# None
#           Survived       Pclass          Age        SibSp        Parch  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.368000     2.327000    30.837300     1.942000     2.032000
# std       0.482503     0.847815    15.996183     1.419384     1.418798
# min       0.000000     1.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000    21.100000     1.000000     1.000000
# 50%       0.000000     3.000000    30.400000     2.000000     2.000000
# 75%       1.000000     3.000000    39.500000     3.000000     3.000000
# max       1.000000     3.000000   150.000000     4.000000     4.000000
#
#               Fare
# count  1000.000000
# mean     57.607590
# std      95.650883
# min       0.110000
# 25%      31.180000
# 50%      51.200000
# 75%      69.692500
# max    1352.300000

# %%
# Missing values
print(df.isnull().sum())
# Out:
# Survived     0
# Pclass       0
# Sex         49
# Age          0
# SibSp        0
# Parch        0
# Fare         0
# Embarked     0
# dtype: int64

# %%
# Visualization 1: Age distribution
plt.figure(figsize=(8,5))
sns.histplot(df['Age'].dropna(), bins=30, kde=True)
plt.title("Age Distribution")
plt.show()

# %%
# Visualization 2: Survival by Sex
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="Sex", hue="Survived")
plt.title("Survival by Sex")
plt.show()

# %%
# Visualization 3: Correlation Heatmap
numeric_df = df.select_dtypes(include=['int64', 'float64'])

plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
